# %%
from gensim.models import LdaModel

lda_model = LdaModel.load('../models/lda/lda_model.gensim')

topics = lda_model.show_topics(num_topics=10, num_words=10, formatted=False)

for topic_id, word_probs in topics:
    print(f'\n➡️ Topic {topic_id}:')
    for word, prob in word_probs:
        print(f'   - {word:<15} {prob:.4f}')
# Out:
# ➡️ Topic 0:
#    - mys             0.0227
#    - onclicklistener 0.0185
#    - twenty          0.0174
#    - windowsdesktop  0.0156
#    - dummy           0.0144
#    - tamil           0.0121
#    - commandlinerunner 0.0102
#    - ispermitted     0.0101
#    - delims          0.0099
#    - servicepointmanager 0.0092
#
# ➡️ Topic 1:
#    - keyalias        0.0254
#    - embedded        0.0233
#    - delims          0.0184
#    - qemu            0.0178
#    - vmstat          0.0144
#    - initializing    0.0142
#    - addasync        0.0137
#    - windowsdesktop  0.0123
#    - withdraw        0.0096
#    - wsi             0.0085
#
# ➡️ Topic 2:
#    - methodcall      0.0624
#    - unplugin        0.0399
#    - keyalias        0.0219
#    - retrain         0.0214
#    - descent         0.0206
#    - springextension 0.0147
#    - ultralytics     0.0147
#    - loadaderror     0.0140
#    - realpath        0.0127
#    - authproperties  0.0125
#
# ➡️ Topic 3:
#    - shake           0.0206
#    - alpinejs        0.0149
#    - thumb           0.0138
#    - paramsserializer 0.0136
#    - listresultsconsumer 0.0127
#    - daemoncommandexecution 0.0118
#    - visible         0.0115
#    - linuxbrew       0.0112
#    - mys             0.0110
#    - cmakeoutput     0.0099
#
# ➡️ Topic 4:
#    - modbus          0.0096
#    - windowsdesktop  0.0086
#    - mypojo          0.0082
#    - jsonwriter      0.0081
#    - dast            0.0079
#    - afternoon       0.0068
#    - delims          0.0062
#    - vmstat          0.0061
#    - writ            0.0057
#    - columnspan      0.0056
#
# ➡️ Topic 5:
#    - sourcesets      0.0538
#    - cmakeoutput     0.0334
#    - exceptionhandlermiddleware 0.0180
#    - ion             0.0163
#    - htmlbuttonelement 0.0144
#    - codecov         0.0141
#    - subtable        0.0140
#    - containerstyle  0.0124
#    - nope            0.0105
#    - dataquery       0.0097
#
# ➡️ Topic 6:
#    - datalabels      0.0372
#    - myqueue         0.0339
#    - subtable        0.0295
#    - cmakeoutput     0.0207
#    - marit           0.0198
#    - incentive       0.0151
#    - hk              0.0149
#    - timeoutseconds  0.0118
#    - rsync           0.0113
#    - complicate      0.0107
#
# ➡️ Topic 7:
#    - addentry        0.0320
#    - lazyliststate   0.0233
#    - callbackfunction 0.0228
#    - fcgi            0.0221
#    - thriller        0.0219
#    - absolutefill    0.0119
#    - aplication      0.0112
#    - nfcmanager      0.0112
#    - userroletype    0.0100
#    - webex           0.0095
#
# ➡️ Topic 8:
#    - webex           0.0310
#    - dones           0.0226
#    - ms              0.0173
#    - qemu            0.0169
#    - granted         0.0166
#    - tinytex         0.0157
#    - cmakeoutput     0.0156
#    - graal           0.0149
#    - minifyreleasewithr 0.0139
#    - windowsdesktop  0.0127
#
# ➡️ Topic 9:
#    - mockdata        0.0208
#    - uninstall       0.0173
#    - webfilter       0.0152
#    - ocaml           0.0151
#    - emit            0.0147
#    - laptime         0.0095
#    - getinitialprops 0.0091
#    - nx              0.0090
#    - booktype        0.0087
#    - kerasregressor  0.0086
